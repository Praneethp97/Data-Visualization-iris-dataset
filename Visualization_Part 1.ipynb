# %%
# box plot---violin plot----scatter plot---bubble plot---histogram

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'iris2.csv')

# %%
df.head(5)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Label
# 0            5.1           3.5            1.4           0.2      0
# 1            4.9           3.0            1.4           0.2      0
# 2            4.7           3.2            1.3           0.2      0
# 3            4.6           3.1            1.5           0.2      0
# 4            5.0           3.6            1.4           0.2      0

# %%
X=df.iloc[:,0:4]   # X=df.drop('Label', axis=1)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # where to find different palette¶
# https://medium.com/@morganjonesartist/color-guide-to-seaborn-palettes-da849406d44f

# %%
# plotting box and violon plot plot using seaborn library

# %%
sns.boxplot(data=X, orient='h', palette='Oranges_r');

# %%
sns.stripplot(data=X, orient='h', palette='Set2');

# %%
sns.boxplot(data=X, orient='h', palette='Set2')       # notch=True
sns.stripplot(data=X, orient='h', palette='Set2');

# %%
sns.boxplot(data=X, orient='h', palette='Set2', notch='True')       # notch=True   # edges on median
sns.stripplot(data=X, orient='h', palette='Set2');

# %% [markdown]
# # What is a violin plot? A violin plot is a hybrid of a box plot and a kernel density plot, which shows peaks in the data. It is used to visualize the distribution of numerical data.
#
#
# ![Picture%2022.jpg](attachment:Picture%2022.jpg)

# %%
sns.violinplot(data=X, orient='h', palette='OrRd');

# %%
sns.stripplot(data=X, orient='v', palette='Set2');

# %%
sns.violinplot(data=X, orient='v', palette='Set2')
sns.stripplot(data=X, orient='v', palette='Set2');

# %% [markdown]
# #   where to find different palette
#
# https://medium.com/@morganjonesartist/color-guide-to-seaborn-palettes-da849406d44f

# %%
# plotting box plot by calling datafram       DataFrame.box.plot()   my dataframe here is X (features)

# %%
X.boxplot();

# %%
# box plot using matplotlib

# %%
plt.boxplot(X);
plt.xticks([1, 2, 3, 4], ['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width']);

# %%
# plot histogram

# %%
X.head(5)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
SL=X['SepalLengthCm']

# %%
type(SL)
# Out:
# pandas.core.series.Series

# %%
plt.hist(SL, bins=30)
plt.xlabel("SepalLength")
plt.ylabel('Value')
plt.title('Sepal Length Histogram');

# %%
# plot bubble charts

# %%
x=np.random.rand(40)
y=np.random.rand(40)
z=np.random.rand(40)

colors=np.random.rand(40)

# use scatter function
plt.scatter(x,y, s=z*1000, c=colors);   # s= size

# %%
# plot scatter plot

# %%
PL=df['PetalLengthCm']
PW=df['PetalWidthCm']
y=df['Label']
plt.scatter(PL, PW, c=y)   # color in terms of label of PL and PW
plt.xlabel('PetalLengthCm')
plt.ylabel('PetalWidthCm')
plt.title('Scatter Plot');

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Label
# 0              5.1           3.5            1.4           0.2      0
# 1              4.9           3.0            1.4           0.2      0
# 2              4.7           3.2            1.3           0.2      0
# 3              4.6           3.1            1.5           0.2      0
# 4              5.0           3.6            1.4           0.2      0
# ..             ...           ...            ...           ...    ...
# 145            6.7           3.0            5.2           2.3      2
# 146            6.3           2.5            5.0           1.9      2
# 147            6.5           3.0            5.2           2.0      2
# 148            6.2           3.4            5.4           2.3      2
# 149            5.9           3.0            5.1           1.8      2
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(data=df, x="PetalLengthCm", y="PetalWidthCm", hue="Label", palette='Accent');
