# %%
# pairplot,  normal distribution, Poisson distribution, binomial distribution

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'iris2.csv')

# %%
df.head(5)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Label
# 0            5.1           3.5            1.4           0.2      0
# 1            4.9           3.0            1.4           0.2      0
# 2            4.7           3.2            1.3           0.2      0
# 3            4.6           3.1            1.5           0.2      0
# 4            5.0           3.6            1.4           0.2      0

# %%
X=df.iloc[:,0:4]

# %%
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
sns.kdeplot(data=X); # kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset

# %% [markdown]
# # What is Kernel Density Function:  https://en.wikipedia.org/wiki/Kernel_density_estimation

# %%
sns.kdeplot(data=X, multiple="stack");

# %%
sns.scatterplot(data=df, x="PetalLengthCm", y="PetalWidthCm", hue="Label", palette='gist_rainbow');

# %% [markdown]
# # Color Guide to Seaborn Palettes
#
# https://medium.com/@morganjonesartist/color-guide-to-seaborn-palettes-da849406d44f

# %%
sns.pairplot(data=df, hue="Label", palette='gist_rainbow_r');

# %%
# plot normal distribution (method 1)

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
plt.hist(x, 50, density=True, facecolor='r', alpha=0.75) # density=true  calculates the probability density function for my X


plt.xlabel('IQ')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025,'$\mu=100,\ \sigma=15$')
plt.xlim(40, 160)
plt.ylim(0, 0.03)
plt.grid(False)
plt.show()

# %%
# plot normal distribution (method 2)

# %% [markdown]
# ![Normal%20Curve.jpeg](attachment:Normal%20Curve.jpeg)

# %%
mu = 121 
sigma = 21
x = mu + sigma * np.random.randn(1000)
   
num_bins = 50
   
n, bins, patches = plt.hist(x, num_bins, 
                            density = 1, 
                            color ='green',
                            alpha = 0.7)
   
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))    # y is probability calculated by formula above 
  
plt.plot(bins, y, '-', color ='blue', linewidth=5)
  
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.grid(True)
plt.title('Normal distribution curve');

# %% [markdown]
# # Plot normal distribution using Scipy library (method 3)
#
# To generate 10000 random numbers from normal distribution mean =0 and variance =1, we use norm.rvs function as

# %%
from scipy.stats import norm
data_normal = norm.rvs(size=10000,loc=0,scale=1)

# %%
ax = sns.distplot(data_normal, kde=True, bins=100, color='skyblue', hist_kws={"linewidth": 25,'alpha':1})

ax.set(xlabel='Normal', ylabel='Frequency');

# %% [markdown]
# # Generate 10000 random numbers from Poisson random variable with mu = 0.3 and plot them.

# %%
from scipy.stats import poisson

data_poisson = poisson.rvs(mu=3, size=10000)
ax = sns.distplot(data_poisson,kde=True,color='red',hist_kws={"linewidth": 15,'alpha':1})

ax.set(xlabel='Poisson', ylabel='Frequency');

# %% [markdown]
# # generate 10000 from binomial distribution and plot the distribution.

# %%
from scipy.stats import binom

data_binom = binom.rvs(n=10,p=0.5,size=10000)
ax = sns.distplot(data_binom, kde=True, color='skyblue', hist_kws={"linewidth": 15,'alpha':1})

ax.set(xlabel='Binomial', ylabel='Frequency');
